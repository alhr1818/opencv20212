# %% [markdown]
# ## Homework4

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('dsu4.png')
rows,cols,ch = img.shape
pts1 = np.float32([[237,269],[570,235],[566,496],[235,462]])
pts2 = np.float32([[200,200],[500,200],[500,400],[200,400]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(1024,768))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-f469729e6103> in <module>
#       1 img = cv2.imread('dsu4.png')
# ----> 2 rows,cols,ch = img.shape
#       3 pts1 = np.float32([[237,269],[570,235],[566,496],[235,462]])
#       4 pts2 = np.float32([[200,200],[500,200],[500,400],[200,400]])
#       5 M = cv2.getPerspectiveTransform(pts1,pts2)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
plt.rcParams["figure.figsize"] = (20,10)
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-f2465188f42c> in <module>
#       1 plt.rcParams["figure.figsize"] = (20,10)
# ----> 2 plt.subplot(121),plt.imshow(img),plt.title('Input')
#       3 plt.subplot(122),plt.imshow(dst),plt.title('Output')
#       4 plt.show()
#
# ~\anaconda3\envs\opencv22\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2722         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2723         data=None, **kwargs):
# -> 2724     __ret = gca().imshow(
#    2725         X, cmap=cmap, norm=norm, aspect=aspect,
#    2726         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# ~\anaconda3\envs\opencv22\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
img = cv2.imread('kakao.jpg')

# %%
rows,cols,ch = img.shape
pts1 = np.float32([[181,125],[719,118],[725,380],[179,376]])
pts2 = np.float32([[100,120],[730,120],[730,370],[100,370]])
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(1024,768))

# %%
plt.rcParams["figure.figsize"] = (20,10)
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()
